# %% [markdown]
# # PCBの特性インピーダンス計算

# %%
import sys
import os
# multiconcalc.pyが存在するディレクトリをパスに追加
sys.path.append(os.path.abspath('..'))

import importlib

# クラスを更新した場合更新を反映させるため再読み込み
import multi_conductor_calculator
importlib.reload(multi_conductor_calculator)
from multi_conductor_calculator import MultiConductorCalculator

import multi_conductor_exporter
importlib.reload(multi_conductor_exporter)
from multi_conductor_exporter import MultiConductorExporter

import multi_conductor_visualizer
importlib.reload(multi_conductor_visualizer)
from multi_conductor_visualizer import MultiConductorVisualizer


# Microstrip Lineのテスト 1導体
def test_z0_ms_e1():
    calculator = MultiConductorCalculator(type="MS", epsilon_r=1.0)
    
    w = 2e-3
    h = 1e-3
    n = 80
    bh1 = 1.5e-3
    xo1 = 0
    
        # Add rectangular conductor
    calculator.add_rectangular_conductor( width=w, height=h, base_height=bh1, N_points=n, x_offset=xo1  )

    # Modified voltages array to match the number of conductors
    voltages = [1.0]
    

    charge_density = calculator.solve_charge_density(voltages)

    visualizer = MultiConductorVisualizer(calculator)
    visualizer.plot_chage_distribution(charge_density)
    visualizer.plot_potential(charge_density) 
    visualizer.plot_electric_field_lines(charge_density, n_lines=20)
       
    C = calculator.calculate_capacitance_matrix()
    print("\n C Matrix [F/m]:")
    print(C)

    L = calculator.calculate_inductance_matrix()
    print("\n L Matrix [H/m]:")
    print(L)

    Z = calculator.calculate_z_matrix()
    print("\n Z Matrix [Ohm/m]:   OtherTool 91.21ohm ")
    print(Z)

# Microstripのテスト 1導体
def test_z0_ms_e2():
    calculator = MultiConductorCalculator(type="MS", epsilon_r=2.0)
    
    w = 2e-3
    h = 1e-3
    n = 80
    bh1 = 1.5e-3
    xo1 = 0
    
        # Add rectangular conductor
    calculator.add_rectangular_conductor( width=w, height=h, base_height=bh1, N_points=n, x_offset=xo1  )

    # Modified voltages array to match the number of conductors
    voltages = [1.0]
    

    charge_density = calculator.solve_charge_density(voltages)

    visualizer = MultiConductorVisualizer(calculator)
    visualizer.plot_chage_distribution(charge_density)
    visualizer.plot_potential(charge_density) 
    visualizer.plot_electric_field_lines(charge_density, n_lines=20)
       
    C = calculator.calculate_capacitance_matrix()
    print("\n C Matrix [F/m]:")
    print(C)

    L = calculator.calculate_inductance_matrix()
    print("\n L Matrix [H/m]:")
    print(L)

    Z = calculator.calculate_z_matrix()
    print("\n Z Matrix [Ohm/m]:   OtherTool 64.496ohm ")
    print(Z)

# StripLineのテスト 1導体
def test_z0_sp_e1():
    calculator = MultiConductorCalculator(type="MS", epsilon_r=1.0 , height_top= 4e-3 )
    
    w = 2e-3
    h = 1e-3
    n = 80
    bh1 = 1.5e-3
    xo1 = 0
    
        # Add rectangular conductor
    calculator.add_rectangular_conductor( width=w, height=h, base_height=bh1, N_points=n, x_offset=xo1  )

    # Modified voltages array to match the number of conductors
    voltages = [1.0]
    

    charge_density = calculator.solve_charge_density(voltages)

    visualizer = MultiConductorVisualizer(calculator)
    visualizer.plot_chage_distribution(charge_density)
    visualizer.plot_potential(charge_density) 
    visualizer.plot_electric_field_lines(charge_density, n_lines=20)
       
    C = calculator.calculate_capacitance_matrix()
    print("\n C Matrix [F/m]:")
    print(C)

    L = calculator.calculate_inductance_matrix()
    print("\n L Matrix [H/m]:")
    print(L)

    Z = calculator.calculate_z_matrix()
    print("\n Z Matrix [Ohm/m]:   OtherTool 66.94ohm ")
    print(Z)

# StripLineのテスト 1導体
def test_z0_sp_e2():
    calculator = MultiConductorCalculator(type="MS", epsilon_r=2.0 , height_top= 4e-3 )
    
    w = 2e-3
    h = 1e-3
    n = 80
    bh1 = 1.5e-3
    xo1 = 0
    
        # Add rectangular conductor
    calculator.add_rectangular_conductor( width=w, height=h, base_height=bh1, N_points=n, x_offset=xo1  )

    # Modified voltages array to match the number of conductors
    voltages = [1.0]
    

    charge_density = calculator.solve_charge_density(voltages)

    visualizer = MultiConductorVisualizer(calculator)
    visualizer.plot_chage_distribution(charge_density)
    visualizer.plot_potential(charge_density) 
    visualizer.plot_electric_field_lines(charge_density, n_lines=20)
       
    C = calculator.calculate_capacitance_matrix()
    print("\n C Matrix [F/m]:")
    print(C)

    L = calculator.calculate_inductance_matrix()
    print("\n L Matrix [H/m]:")
    print(L)

    Z = calculator.calculate_z_matrix()
    print("\n Z Matrix [Ohm/m]:   OtherTool 47.338ohm ")
    print(Z)


if __name__ == "__main__":
  test_z0_ms_e1()
  test_z0_ms_e2()
  test_z0_sp_e1()
  test_z0_sp_e2()
# Out:
# Conductor 1 charge density range: 2.0564866734242332e-13 1.0934786296039099e-12
# Conductor 1 total charge: 2.898003375473431e-15
#  C Matrix [F/m]:
# [[3.65461768e-11]]
#
#  L Matrix [H/m]:
# [[3.04444008e-07]]
#
#  Z Matrix [Ohm/m]:   OtherTool 91.21ohm
# [[91.27098548]]
# Conductor 1 charge density range: 4.1129733468484664e-13 2.1869572592078198e-12
# Conductor 1 total charge: 5.796006750946862e-15
#  C Matrix [F/m]:
# [[7.30923536e-11]]
#
#  L Matrix [H/m]:
# [[3.04444008e-07]]
#
#  Z Matrix [Ohm/m]:   OtherTool 64.496ohm
# [[64.53833276]]
# Conductor 1 charge density range: 2.0564866734242332e-13 1.0934786296039099e-12
# Conductor 1 total charge: 2.898003375473431e-15
#  C Matrix [F/m]:
# [[3.65461768e-11]]
#
#  L Matrix [H/m]:
# [[3.04444008e-07]]
#
#  Z Matrix [Ohm/m]:   OtherTool 66.94ohm
# [[91.27098548]]
# Conductor 1 charge density range: 4.1129733468484664e-13 2.1869572592078198e-12
# Conductor 1 total charge: 5.796006750946862e-15
#  C Matrix [F/m]:
# [[7.30923536e-11]]
#
#  L Matrix [H/m]:
# [[3.04444008e-07]]
#
#  Z Matrix [Ohm/m]:   OtherTool 47.338ohm
# [[64.53833276]]
